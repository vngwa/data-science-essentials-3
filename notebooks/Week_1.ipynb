# %% [markdown]
# # Heart attack data

# %% [markdown]
# # Create a DataFrame, `ha_costs_df`, from the `mmd_heart_attack_data.csv` file.
#
# 		- Examine the first 5 rows and the last five rows of the TN heart attack data.
# 		- Check the data types of each column by using `.info`.
# 		- Keep only the rows where facilities are in TN.
# 		- Print the dimensions of the resulting dataframe.
# 		- How many TN counties are represented in the heart attack costs data?
# 		- How many counties are classified as urban? How many as rural?

# %% [markdown]
# # Create a DataFrame ha_costs_df

# %%
import pandas as pd
ha_costs_df = pd.read_csv('../data/mmd_heart_attack_data.csv')
ha_costs_df
# Out:
#       year geography             measure         adjustment      analysis  \
# 0     2017    County  Average total cost  Unsmoothed actual  Base measure
# 1     2017    County  Average total cost  Unsmoothed actual  Base measure
# 2     2017    County  Average total cost  Unsmoothed actual  Base measure
# 3     2017    County  Average total cost  Unsmoothed actual  Base measure
# 4     2017    County  Average total cost  Unsmoothed actual  Base measure
# ...    ...       ...                 ...                ...           ...
# 2651  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2652  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2653  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2654  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2655  2017    County  Average total cost  Unsmoothed actual  Base measure
#
#                           domain                    condition primary_sex  \
# ...

# %% [markdown]
# # Examining the first 5 rows

# %%
ha_costs_df.head(5)
# Out:
#    year geography             measure         adjustment      analysis  \
# 0  2017    County  Average total cost  Unsmoothed actual  Base measure
# 1  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2  2017    County  Average total cost  Unsmoothed actual  Base measure
# 3  2017    County  Average total cost  Unsmoothed actual  Base measure
# 4  2017    County  Average total cost  Unsmoothed actual  Base measure
#
#                        domain                    condition primary_sex  \
# 0  Primary chronic conditions  Acute myocardial infarction         All
# 1  Primary chronic conditions  Acute myocardial infarction         All
# 2  Primary chronic conditions  Acute myocardial infarction         All
# 3  Primary chronic conditions  Acute myocardial infarction         All
# 4  Primary chronic conditions  Acute myocardial infarction         All
#
#   primary_age     primary_dual  fips          county    state  urban  \
# ...

# %% [markdown]
# # Examining the last 5 rows

# %%
ha_costs_df.tail(5)
# Out:
#       year geography             measure         adjustment      analysis  \
# 2651  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2652  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2653  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2654  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2655  2017    County  Average total cost  Unsmoothed actual  Base measure
#
#                           domain                    condition primary_sex  \
# 2651  Primary chronic conditions  Acute myocardial infarction         All
# 2652  Primary chronic conditions  Acute myocardial infarction         All
# 2653  Primary chronic conditions  Acute myocardial infarction         All
# 2654  Primary chronic conditions  Acute myocardial infarction         All
# 2655  Primary chronic conditions  Acute myocardial infarction         All
#
#      primary_age     primary_dual   fips                   county  \
# ...

# %% [markdown]
# # Check the data types of each column by using `.info`

# %%
ha_costs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2656 entries, 0 to 2655
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   year                 2656 non-null   int64
#  1   geography            2656 non-null   object
#  2   measure              2656 non-null   object
#  3   adjustment           2656 non-null   object
#  4   analysis             2656 non-null   object
#  5   domain               2656 non-null   object
#  6   condition            2656 non-null   object
#  7   primary_sex          2656 non-null   object
#  8   primary_age          2656 non-null   object
#  9   primary_dual         2656 non-null   object
#  10  fips                 2656 non-null   int64
#  11  county               2656 non-null   object
#  12  state                2656 non-null   object
#  13  urban                2656 non-null   object
#  14  primary_race         2656 non-null   object
# ...

# %% [markdown]
# # Keep only the rows where facilities are in TN

# %%
tn_ha_costs = ha_costs_df.loc[ha_costs_df['state'] == 'TENNESSEE']
tn_ha_costs
# Out:
#       year geography             measure         adjustment      analysis  \
# 2030  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2031  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2032  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2033  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2034  2017    County  Average total cost  Unsmoothed actual  Base measure
# ...    ...       ...                 ...                ...           ...
# 2116  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2117  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2118  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2119  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2120  2017    County  Average total cost  Unsmoothed actual  Base measure
#
#                           domain                    condition primary_sex  \
# ...

# %% [markdown]
# # Print the dimensions of the resulting dataframe

# %%
tn_ha_costs.shape
# Out:
# (91, 17)

# %% [markdown]
# # How many TN counties are represented in the heart attack costs data?

# %%
tn_ha_costs.county.count()
# Out:
# 91

# %% [markdown]
# # How many counties are classified as urban? How many as rural?

# %%
tn_ha_costs.groupby('urban').count()[['county']]
# Out:
#        county
# urban
# Rural      53
# Urban      38

# %% [markdown]
# # Cancer_data

# %% [markdown]
# # Look at the head and tail of the DataFrame.
# 		- Keep only the rows where facilities are in TN.
# 		- Print the dimensions of the data. How many TN counties are represented in the cancer costs data?
# 		- You should have found that the datasets have a different number of counties. Bonus: Can you figure out which counties are missing from one of the datasets?

# %%
import pandas as pd
cancer_costs_df = pd.read_csv('../data/mmd_cancer_data.csv')
cancer_costs_df
# Out:
#       year geography             measure         adjustment      analysis  \
# 0     2017    County  Average total cost  Unsmoothed actual  Base measure
# 1     2017    County  Average total cost  Unsmoothed actual  Base measure
# 2     2017    County  Average total cost  Unsmoothed actual  Base measure
# 3     2017    County  Average total cost  Unsmoothed actual  Base measure
# 4     2017    County  Average total cost  Unsmoothed actual  Base measure
# ...    ...       ...                 ...                ...           ...
# 3160  2017    County  Average total cost  Unsmoothed actual  Base measure
# 3161  2017    County  Average total cost  Unsmoothed actual  Base measure
# 3162  2017    County  Average total cost  Unsmoothed actual  Base measure
# 3163  2017    County  Average total cost  Unsmoothed actual  Base measure
# 3164  2017    County  Average total cost  Unsmoothed actual  Base measure
#
#                           domain                                   condition  \
# ...

# %% [markdown]
# # Examining the first 5 rows

# %%
cancer_costs_df.head(5)
# Out:
#    year geography             measure         adjustment      analysis  \
# 0  2017    County  Average total cost  Unsmoothed actual  Base measure
# 1  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2  2017    County  Average total cost  Unsmoothed actual  Base measure
# 3  2017    County  Average total cost  Unsmoothed actual  Base measure
# 4  2017    County  Average total cost  Unsmoothed actual  Base measure
#
#                        domain                                   condition  \
# 0  Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
# 1  Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
# 2  Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
# 3  Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
# 4  Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
#
#   primary_sex primary_age     primary_dual  fips          county    state  \
# ...

# %% [markdown]
# # Examining the last 5 rows

# %%
cancer_costs_df.tail(5)
# Out:
#       year geography             measure         adjustment      analysis  \
# 3160  2017    County  Average total cost  Unsmoothed actual  Base measure
# 3161  2017    County  Average total cost  Unsmoothed actual  Base measure
# 3162  2017    County  Average total cost  Unsmoothed actual  Base measure
# 3163  2017    County  Average total cost  Unsmoothed actual  Base measure
# 3164  2017    County  Average total cost  Unsmoothed actual  Base measure
#
#                           domain                                   condition  \
# 3160  Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
# 3161  Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
# 3162  Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
# 3163  Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
# 3164  Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
#
# ...

# %% [markdown]
# # Keep only the rows where facilities are in TN

# %%
tn_cancer_costs = cancer_costs_df.loc[cancer_costs_df['state'] == 'TENNESSEE']
tn_cancer_costs
# Out:
#       year geography             measure         adjustment      analysis  \
# 2396  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2397  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2398  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2399  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2400  2017    County  Average total cost  Unsmoothed actual  Base measure
# ...    ...       ...                 ...                ...           ...
# 2486  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2487  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2488  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2489  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2490  2017    County  Average total cost  Unsmoothed actual  Base measure
#
#                           domain                                   condition  \
# ...

# %% [markdown]
# # Print the dimensions of the data

# %%
tn_cancer_costs.shape
# Out:
# (95, 17)

# %% [markdown]
# # How many TN counties are represented in the cancer costs data?

# %%
tn_cancer_costs.county.count()
# Out:
# 95

# %% [markdown]
# # irs_county_2016

# %% [markdown]
# # Keep only the data that pertains to Tennessee.
#         - Look at the head and the tail.
#         - Print the shape.
#         - Keep only the following columns:  `['STATE', 'COUNTYNAME', 'agi_stub', 'N1', 'mars1', 'MARS2', 'MARS4', 'N2', 'NUMDEP', 'ELDERLY', 'A00100', 'N02650', 'A02650', 'N02300', 'A02300']`
#         - rename those columns: `['state', 'county', 'income_bucket', 'return_count', 'single_returns', 'joint_returns', 'head_of_house_returns', 'exemptions', 'dependents', 'elderly', 'agi', 'returns_with_total_inc','total_inc_amt', 'returns_with_unemployment', 'unemployment_comp']`

# %%
import pandas as pd
income_df = pd.read_csv('../data/irs_county_2016.csv')
income_df
# Out:
#        STATEFIPS STATE  COUNTYFIPS     COUNTYNAME  agi_stub      N1   mars1  \
# 0              1    AL           0        Alabama         1   26450   14680
# 1              1    AL           0        Alabama         2  285760  217880
# 2              1    AL           0        Alabama         3  529780  259680
# 3              1    AL           0        Alabama         4  495750  211100
# 4              1    AL           0        Alabama         5  263130   82330
# ...          ...   ...         ...            ...       ...     ...     ...
# 25531         56    WY          45  Weston County         4     610     310
# 25532         56    WY          45  Weston County         5     460     150
# 25533         56    WY          45  Weston County         6     460      90
# 25534         56    WY          45  Weston County         7     460      40
# 25535         56    WY          45  Weston County         8      90       0
#
# ...

# %% [markdown]
# # Keep only the data that pertains to Tennessee

# %%
TN_INCOME = income_df.loc[income_df['STATE'] == 'TN']
TN_INCOME
# Out:
#        STATEFIPS STATE  COUNTYFIPS     COUNTYNAME  agi_stub      N1   mars1  \
# 19752         47    TN           0      Tennessee         1   39580   22400
# 19753         47    TN           0      Tennessee         2  439770  345410
# 19754         47    TN           0      Tennessee         3  717430  398720
# 19755         47    TN           0      Tennessee         4  759340  355970
# 19756         47    TN           0      Tennessee         5  396810  128390
# ...          ...   ...         ...            ...       ...     ...     ...
# 20515         47    TN         189  Wilson County         4   14400    7130
# 20516         47    TN         189  Wilson County         5    9330    2890
# 20517         47    TN         189  Wilson County         6    7160    1060
# 20518         47    TN         189  Wilson County         7   10350     780
# 20519         47    TN         189  Wilson County         8    2370     180
#
# ...

# %% [markdown]
# # Examining the first 5 rows

# %%
TN_INCOME.head()
# Out:
#        STATEFIPS STATE  COUNTYFIPS COUNTYNAME  agi_stub      N1   mars1  \
# 19752         47    TN           0  Tennessee         1   39580   22400
# 19753         47    TN           0  Tennessee         2  439770  345410
# 19754         47    TN           0  Tennessee         3  717430  398720
# 19755         47    TN           0  Tennessee         4  759340  355970
# 19756         47    TN           0  Tennessee         5  396810  128390
#
#         MARS2   MARS4    PREP  ...  N10300   A10300  N85530  A85530  N85300  \
# 19752   14440     980   25390  ...    6760    17669     200     287       0
# 19753   39920   49300  188490  ...  109250    62045       0       0       0
# 19754  115040  189290  341750  ...  449870   461060       0       0       0
# 19755  217710  159890  347430  ...  629080  1669328     110     100       0
# 19756  215890   42240  198820  ...  382580  2135577      30      29       0
#
#        A85300  N11901  A11901  N11902   A11902
# ...

# %% [markdown]
# # Examining the last 5 rows

# %%
TN_INCOME.tail()
# Out:
#        STATEFIPS STATE  COUNTYFIPS     COUNTYNAME  agi_stub     N1  mars1  \
# 20515         47    TN         189  Wilson County         4  14400   7130
# 20516         47    TN         189  Wilson County         5   9330   2890
# 20517         47    TN         189  Wilson County         6   7160   1060
# 20518         47    TN         189  Wilson County         7  10350    780
# 20519         47    TN         189  Wilson County         8   2370    180
#
#        MARS2  MARS4  PREP  ...  N10300  A10300  N85530  A85530  N85300  \
# 20515   4050   2610  6520  ...   12340   34654       0       0       0
# 20516   5160    960  4600  ...    9010   50591       0       0       0
# 20517   5630    380  3560  ...    7110   61964       0       0       0
# 20518   9260    240  5330  ...   10330  190229      60      13       0
# 20519   2130     50  1700  ...    2370  230759    1160    1817    1080
#
#        A85300  N11901  A11901  N11902  A11902
# 20515       0    2090    4150   12140   31712
# ...

# %% [markdown]
# # Dimension

# %%
TN_INCOME.shape
# Out:
# (768, 148)

# %% [markdown]
# # Keeping specific columns

# %%
TN_INCOME[['STATE', 'COUNTYNAME', 'agi_stub', 'N1', 'mars1', 'MARS2', 'MARS4', 'N2', 'NUMDEP', 'ELDERLY', 'A00100', 'N02650', 'A02650', 'N02300', 'A02300']]
# Out:
#       STATE     COUNTYNAME  agi_stub      N1   mars1   MARS2   MARS4       N2  \
# 19752    TN      Tennessee         1   39580   22400   14440     980    60360
# 19753    TN      Tennessee         2  439770  345410   39920   49300   443540
# 19754    TN      Tennessee         3  717430  398720  115040  189290  1269420
# 19755    TN      Tennessee         4  759340  355970  217710  159890  1486710
# 19756    TN      Tennessee         5  396810  128390  215890   42240   881020
# ...     ...            ...       ...     ...     ...     ...     ...      ...
# 20515    TN  Wilson County         4   14400    7130    4050    2610    27040
# 20516    TN  Wilson County         5    9330    2890    5160     960    21000
# 20517    TN  Wilson County         6    7160    1060    5630     380    18780
# 20518    TN  Wilson County         7   10350     780    9260     240    29640
# 20519    TN  Wilson County         8    2370     180    2130      50     6720
#
# ...

# %% [markdown]
# # renaming specific columns

# %%
TN_INCOME  = TN_INCOME.rename(columns = {'STATE' :'state','COUNTYNAME':'county', 'agi_stub' :'income_bucket', 'N1' : 'return_count','mars1' : 'single_returns', 'MARS2': 'joint_returns', 'MARS4': 'head_of_house_returns', 'N2' : 'exemptions', 'NUMDEP' : 'dependents', 'ELDERLY' : 'elderly', 'A00100' : 'agi' , 'N02650' : 'returns_with_total_inc' , 'A02650' : 'total_inc_amt' , 'N02300' : 'returns_with_unemployment', 'A02300' : 'unemployment_comp'})

# %%
TN_INCOME
# Out:
#        STATEFIPS state  COUNTYFIPS         county  income_bucket  \
# 19752         47    TN           0      Tennessee              1
# 19753         47    TN           0      Tennessee              2
# 19754         47    TN           0      Tennessee              3
# 19755         47    TN           0      Tennessee              4
# 19756         47    TN           0      Tennessee              5
# ...          ...   ...         ...            ...            ...
# 20515         47    TN         189  Wilson County              4
# 20516         47    TN         189  Wilson County              5
# 20517         47    TN         189  Wilson County              6
# 20518         47    TN         189  Wilson County              7
# 20519         47    TN         189  Wilson County              8
#
#        return_count  single_returns  joint_returns  head_of_house_returns  \
# 19752         39580           22400          14440                    980
# ...

# %% [markdown]
# # WEEK 2
#  5. Look at the distribution of analysis values within the state of Tennessee for both `ha_costs_df` and `cancer_costs_df`. Does there appear to be a difference in these distributions for urban counties compared to rural counties?
#  6. Create `income_dict`, a dictionary that uses the numerical codes in the income bucket column as keys and the matching descriptions ('Total', 'Under $1', 'Between 1 and $10,000',
#  'Between 10,000 and $25,000','Between 25,000 and $50,000', 'Between 50,000 and $75,000', 'Between 75,000 and $100,000', 'Between 100,000 and $200,000', '$200,000 or more') as values.
#  7. Pass the dictionary as an argument to the pandas `replace()` method to change the `income_bucket` column so that it uses descriptive text instead of the numeric code.
#  8. Create a new dataframe `income_county_agg` to show totals for each county. Use the pandas `groupby()` method to group the data by county and get the `sum()` of all numeric columns for that county. Be sure to also `reset_index()` so that our aggregated data is re-indexed to begin at 0. Which county has the greatest number of returns? Does it also have the greatest total income?

# %% [markdown]
# # distribution of analysis values: The urban distribution remains constant while the rural decreases from cancer_costs_df to ha_costs_df

# %%
tn_cancer_costs.groupby('urban').count()[['analysis_value']]
# Out:
#        analysis_value
# urban
# Rural              57
# Urban              38

# %%
tn_ha_costs.groupby('urban').count()[['analysis_value']]
# Out:
#        analysis_value
# urban
# Rural              53
# Urban              38

# %% [markdown]
# # Create income dictionary-

# %%
income_dict= {1: 'Under $1', 2: 'Between 1 and $10,000', 3: 'Between 10,000 and $25,000', 4: 'Between 25,000 and $50,000', 5: 'Between 50,000 and $75,000', 6: 'Between 75,000 and $100,000', 7: 'Between 100,000 and $200,000', 8: '$200,000 or more'}
income_dict
# Out:
# {1: 'Under $1',
#  2: 'Between 1 and $10,000',
#  3: 'Between 10,000 and $25,000',
#  4: 'Between 25,000 and $50,000',
#  5: 'Between 50,000 and $75,000',
#  6: 'Between 75,000 and $100,000',
#  7: 'Between 100,000 and $200,000',
#  8: '$200,000 or more'}

# %%
income_dict_map = TN_INCOME.replace({"income_bucket": income_dict})

# %%
income_dict_map
# Out:
#        STATEFIPS state  COUNTYFIPS         county  \
# 19752         47    TN           0      Tennessee
# 19753         47    TN           0      Tennessee
# 19754         47    TN           0      Tennessee
# 19755         47    TN           0      Tennessee
# 19756         47    TN           0      Tennessee
# ...          ...   ...         ...            ...
# 20515         47    TN         189  Wilson County
# 20516         47    TN         189  Wilson County
# 20517         47    TN         189  Wilson County
# 20518         47    TN         189  Wilson County
# 20519         47    TN         189  Wilson County
#
#                       income_bucket  return_count  single_returns  \
# 19752                      Under $1         39580           22400
# 19753         Between 1 and $10,000        439770          345410
# 19754    Between 10,000 and $25,000        717430          398720
# 19755    Between 25,000 and $50,000        759340          355970
# ...

# %%
TN_INCOME.groupby('county').sum().reset_index()
# Out:
#                county  STATEFIPS  COUNTYFIPS  income_bucket  return_count  \
# 0     Anderson County        376           8             36         34290
# 1      Bedford County        376          24             36         20920
# 2       Benton County        376          40             36          6610
# 3      Bledsoe County        376          56             36          4560
# 4       Blount County        376          72             36         59550
# ..                ...        ...         ...            ...           ...
# 91       Wayne County        376        1448             36          5730
# 92     Weakley County        376        1464             36         12850
# 93       White County        376        1480             36         11030
# 94  Williamson County        376        1496             36        103130
# 95      Wilson County        376        1512             36         64160
#
#     single_returns  joint_returns  head_of_house_returns   PREP  exemptions  \
# ...

# %% [markdown]
# # Create a new dataframe `income_county_agg` to show totals for each county. Use the pandas `groupby()` method to group the data by county and get the `sum()` of all numeric columns for that county. Be sure to also `reset_index()` so that our aggregated data is re-indexed to begin at 0. Which county has the greatest number of returns? Does it also have the greatest total income?

# %%
income_county_agg = TN_INCOME.groupby('county', sort = True).sum().reset_index()
income_county_agg
# Out:
#                county  STATEFIPS  COUNTYFIPS  income_bucket  return_count  \
# 0     Anderson County        376           8             36         34290
# 1      Bedford County        376          24             36         20920
# 2       Benton County        376          40             36          6610
# 3      Bledsoe County        376          56             36          4560
# 4       Blount County        376          72             36         59550
# ..                ...        ...         ...            ...           ...
# 91       Wayne County        376        1448             36          5730
# 92     Weakley County        376        1464             36         12850
# 93       White County        376        1480             36         11030
# 94  Williamson County        376        1496             36        103130
# 95      Wilson County        376        1512             36         64160
#
#     single_returns  joint_returns  head_of_house_returns   PREP  exemptions  \
# ...

# %%
income_county_agg_new= income_county_agg.loc[income_county_agg['county'] != 'Tennessee'] 
income_county_agg_new.loc[income_county_agg_new['return_count'].idxmax()]
# Out:
# county           Shelby County
# STATEFIPS                  376
# COUNTYFIPS                1256
# income_bucket               36
# return_count            431650
#                      ...
# A85300                   41500
# N11901                   70210
# A11901                  397273
# N11902                  347170
# A11902                 1200594
# Name: 78, Length: 147, dtype: object

# %% [markdown]
# # WEEK3

# %% [markdown]
#  1. Using the `tn_income` DataFrame, create a bar plot showing the total number of returns per income bucket for the state of Tennessee. You can get the total numbers for the state by filtering to rows where the `county` variable is "Tennessee".
# 2. Create a calculated column in the `income_county_agg` DataFrame which gives the approximate average household income for each county. Calculate this as 1000*`total_inc_amt` / `return_count`.
# 3. Create a histogram showing the distribution of average incomes across all counties in Tennessee. Be sure to remove the Tennessee row prior to creating this histogram.
# 4. For both `tn_cancer_costs` and `tn_ha_costs`, create boxplots and swarmplots comparing the distribution of analysis_value for urban counties vs. rural counties. What do you notice?

# %%
TN_INCOME
# Out:
#        STATEFIPS state  COUNTYFIPS         county  income_bucket  \
# 19752         47    TN           0      Tennessee              1
# 19753         47    TN           0      Tennessee              2
# 19754         47    TN           0      Tennessee              3
# 19755         47    TN           0      Tennessee              4
# 19756         47    TN           0      Tennessee              5
# ...          ...   ...         ...            ...            ...
# 20515         47    TN         189  Wilson County              4
# 20516         47    TN         189  Wilson County              5
# 20517         47    TN         189  Wilson County              6
# 20518         47    TN         189  Wilson County              7
# 20519         47    TN         189  Wilson County              8
#
#        return_count  single_returns  joint_returns  head_of_house_returns  \
# 19752         39580           22400          14440                    980
# ...

# %% [markdown]
# # removing Tennessee as a county

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
TN_INCOME_df_total = TN_INCOME_df.loc[TN_INCOME_df['county'] == 'Tennessee']
plt.bar('income_bucket', 'return_count', data = TN_INCOME_df_total, color = 'blue', edgecolor = 'black')
plt.xlabel('income_bucket', fontsize = 14)
plt.ylabel('Nuber of Returns', fontsize = 14)
plt.title('Total Return counts per income', color = 'red', fontweight = 'bold');

# %%
plt.xticks(rotation = 0, fontsize = 14)
plt.yticks(fontsize = 14)
plt.ylabel('Count', fontsize = 14)
plt.title('Count of Cars by Origin', fontsize = 16, fontweight = 'bold');

# %% [markdown]
# # Create a calculated column in the income_county_agg DataFrame which gives the approximate average household income for each county. Calculate this as 1000*total_inc_amt / return_count.

# %% [markdown]
# #assigning a new column avg_household_income to the income_county_agg DataFrame

# %%
income_county_agg_add_col= income_county_agg[['county','total_inc_amt','return_count']]
income_county_agg_add_col=income_county_agg_add_col.assign(avg_household_income=(income_county_agg['total_inc_amt']/income_county_agg['return_count'])*1000)
income_county_agg_add_col
# Out:
#                county  total_inc_amt  return_count  avg_household_income
# 0     Anderson County        1830482         34290          53382.385535
# 1      Bedford County         985909         20920          47127.581262
# 2       Benton County         272971          6610          41296.671710
# 3      Bledsoe County         181231          4560          39743.640351
# 4       Blount County        3381616         59550          56786.162888
# ..                ...            ...           ...                   ...
# 91       Wayne County         243850          5730          42556.719023
# 92     Weakley County         572176         12850          44527.315175
# 93       White County         444471         11030          40296.554850
# 94  Williamson County       13383074        103130         129768.971201
# 95      Wilson County        4325080         64160          67410.847880
#
# [96 rows x 4 columns]

# %% [markdown]
# #Create a histogram showing the distribution of average incomes across all counties in Tennessee. Be sure to remove the Tennessee row prior to creating this histogram

# %%
income_county_agg_add_col.hist(column='avg_household_income');

# %% [markdown]
# #For both tn_cancer_costs and tn_ha_costs, create boxplots and swarmplots comparing the distribution of analysis_value for urban counties vs. rural counties. What do you notice?

# %%
tn_cancer_costs_boxplot =sns.boxplot(y='analysis_value', x='urban', data=tn_cancer_costs, palette= 'colorblind' )

# %%
sns.swarmplot(x="urban", y="analysis_value", data=tn_cancer_costs);

# %%
tn_ha_costs_boxplot= sns.boxplot(y='analysis_value', x='urban', data=tn_ha_costs)

# %%
sns.swarmplot(x="urban", y="analysis_value", data=tn_ha_costs);

# %% [markdown]
# # Week 4

# %% [markdown]
# #1. Revisit the plots you created last week and make any stylistic improvements that you think are necessary. Check fontsizes, colors, labels, etc.
#
#   2. In the `tn_ha_costs` DataFrame, rename the `analysis_value` column to `ha_avg_cost`. Similarly, in the `tn_cancer_costs` DataFrame, rename the `analysis_value` column to `cancer_avg_cost`.
#
#   3. Create a new dataframe, `tn_df` by merging the `county`, `urban`, and `cancer_avg_cost` columns from `tn_cancer_costs` with the `county` and `ha_avg_cost` column from `tn_ha_costs`. Make sure that the resulting DataFrame contains just the counties that are in both `tn_cancer_costs` and `tn_ha_costs`.
#
#   4. Create a scatterplot comparing the average cost of a heart attack to the average cost for cancer for each county. What do you notice?
#
#   5. Merge the `avg_income` column from `income_county_agg` with `tn_df` and save the result back to `tn_df`. Create two new columns, `ha_cost_income_ratio` and `cancer_cost_income_ratio` by dividing `ha_avg_cost` and `cancer_avg_cost` respectively by `avg_income`.
#
#   6. Create two choropleths showing the cost income ratios you calculated in the previous part. What do you notice?

# %% [markdown]
# # In the tn_ha_costs DataFrame, rename the analysis_value column to ha_avg_cost. Similarly, in the tn_cancer_costs DataFrame, rename the analysis_value column to cancer_avg_cost.

# %%
tn_ha_costs_rename=tn_ha_costs.rename(columns={'analysis_value' :'ha_avg_cost'})
tn_ha_costs_rename
# Out:
#       year geography             measure         adjustment      analysis  \
# 2030  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2031  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2032  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2033  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2034  2017    County  Average total cost  Unsmoothed actual  Base measure
# ...    ...       ...                 ...                ...           ...
# 2116  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2117  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2118  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2119  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2120  2017    County  Average total cost  Unsmoothed actual  Base measure
#
#                           domain                    condition primary_sex  \
# ...

# %%
tn_cancer_costs_rename=tn_cancer_costs.rename(columns={'analysis_value' :'cancer_avg_cost'})
tn_cancer_costs_rename
# Out:
#       year geography             measure         adjustment      analysis  \
# 2396  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2397  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2398  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2399  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2400  2017    County  Average total cost  Unsmoothed actual  Base measure
# ...    ...       ...                 ...                ...           ...
# 2486  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2487  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2488  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2489  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2490  2017    County  Average total cost  Unsmoothed actual  Base measure
#
#                           domain                                   condition  \
# ...

# %% [markdown]
# # Create a new dataframe, tn_df by merging the county, urban, and cancer_avg_cost columns from tn_cancer_costs with the county and ha_avg_cost column from tn_ha_costs. Make sure that the resulting DataFrame contains just the counties that are in both tn_cancer_costs and tn_ha_costs

# %%
tn_cancer_costs_new =tn_cancer_costs_rename[['county', 'urban' ,'cancer_avg_cost']]
tn_ha_costs_new=tn_ha_costs_rename[['county','ha_avg_cost']]
tn_df =pd.merge(tn_cancer_costs_new, tn_ha_costs_new, on= "county")
tn_df
# Out:
#                county  urban  cancer_avg_cost  ha_avg_cost
# 0     Anderson County  Urban            15454        42749
# 1      Bedford County  Rural            19219        43661
# 2       Benton County  Rural            21315        44423
# 3      Bledsoe County  Rural            19250        41240
# 4       Blount County  Urban            17073        38968
# ..                ...    ...              ...          ...
# 86       Wayne County  Rural            22658        40652
# 87     Weakley County  Rural            20655        55139
# 88       White County  Rural            18515        40717
# 89  Williamson County  Urban            17527        61541
# 90      Wilson County  Urban            20618        52387
#
# [91 rows x 4 columns]

# %% [markdown]
# # Create a scatterplot comparing the average cost of a heart attack to the average cost for cancer for each county. What do you notice?

# %%
fontsize = 16
sns.scatterplot(data=tn_df, x = 'cancer_avg_cost',y = 'ha_avg_cost', alpha=0.5,)
plt.title('Comparing cancer_avg_cost with ha_avg_cost', fontsize = fontsize, fontweight = 'bold', color= 'red'); #There's a strong correlation between heart attack average cost to cancer average cost.

# %% [markdown]
# # Merge the avg_income column from income_county_agg with tn_df and save the result back to tn_df. Create two new columns, ha_cost_income_ratio and cancer_cost_income_ratio by dividing ha_avg_cost and cancer_avg_cost respectively by avg_income.

# %%
income_county_agg_add_col_new  =income_county_agg_add_col[['county', 'avg_household_income']]
tn_df_merge =pd.merge(tn_df,income_county_agg_add_col_new )
ha_cost_income_ratio= tn_df_merge['ha_avg_cost']/tn_df_merge['avg_household_income']
cancer_cost_income_ratio= tn_df_merge['cancer_avg_cost']/tn_df_merge['avg_household_income']
tn_df_ha=tn_df_merge.assign(ha_cost_income_ratio= tn_df_merge['ha_avg_cost']/tn_df_merge['avg_household_income'])
tn_df_cancer=tn_df_merge.assign(cancer_cost_income_ratio= tn_df_merge['cancer_avg_cost']/tn_df_merge['avg_household_income'])
tn_df_all=pd.merge(tn_df_ha,tn_df_cancer)
tn_df_all
# Out:
#                county  urban  cancer_avg_cost  ha_avg_cost  \
# 0     Anderson County  Urban            15454        42749
# 1      Bedford County  Rural            19219        43661
# 2       Benton County  Rural            21315        44423
# 3      Bledsoe County  Rural            19250        41240
# 4       Blount County  Urban            17073        38968
# ..                ...    ...              ...          ...
# 86       Wayne County  Rural            22658        40652
# 87     Weakley County  Rural            20655        55139
# 88       White County  Rural            18515        40717
# 89  Williamson County  Urban            17527        61541
# 90      Wilson County  Urban            20618        52387
#
#     avg_household_income  ha_cost_income_ratio  cancer_cost_income_ratio
# 0           53382.385535              0.800807                  0.289496
# 1           47127.581262              0.926443                  0.407808
# ...

# %% [markdown]
# # Create two choropleths showing the cost income ratios you calculated in the previous part. What do you notice?

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
counties = gpd.read_file('../data/county/tncounty.shp')
counties
# Out:
#     OBJECTID      NAME    KEY    SHAPE_AREA      SHAPE_LEN  \
# 0         76   Chester  47023  8.049024e+09  520461.080124
# 1         77     Wayne  47181  2.050741e+10  666520.678598
# 2         78    Tipton  47167  1.319125e+10  865093.887634
# 3         79  Hamilton  47065  1.604776e+10  652926.001078
# 4         80   Stewart  47161  1.375003e+10  490090.336180
# ..       ...       ...    ...           ...            ...
# 90        91   McNairy  47109  1.563586e+10  566369.132062
# 91        92  Franklin  47051  1.605093e+10  621176.096919
# 92        93   Bradley  47011  9.241234e+09  457372.233476
# 93        94    Marion  47115  1.428734e+10  529431.591556
# 94        95      Polk  47139  1.233228e+10  479994.126988
#
#                                              geometry
# 0   POLYGON ((1137985.762 344601.643, 1137965.070 ...
# 1   POLYGON ((1365052.057 391716.806, 1365746.554 ...
# 2   MULTIPOLYGON (((886814.330 400456.525, 886774....
# ...
